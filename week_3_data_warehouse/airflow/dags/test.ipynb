# %%
import pandas as pd
import os

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '~/.google/credentials/google_credentials.json'

# pd.read_parquet("gs://dtc_data_lake_sustained-hold-325323/green/green_tripdata_2020-02.parquet").dtypes

# %%
fhv = pd.read_gbq("""
    WITH sub AS (
        SELECT * FROM `sustained-hold-325323.trips_data_all.fhv_tripdata_external_table`
        UNION ALL 
        SELECT * FROM `sustained-hold-325323.trips_data_all.fhv_tripdata_external_table_202001`
    )
    SELECT * FROM sub ORDER BY pickup_datetime
""", project_id='sustained-hold-325323')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1571773/656599926.py in <module>
# ----> 1 fhv = pd.read_gbq("""
#       2     WITH sub AS (
#       3         SELECT * FROM `sustained-hold-325323.trips_data_all.fhv_tripdata_external_table`
#       4         UNION ALL
#       5         SELECT * FROM `sustained-hold-325323.trips_data_all.fhv_tripdata_external_table_202001`
#
# ~/.local/lib/python3.9/site-packages/pandas/io/gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, max_results, progress_bar_type)
#     181     # END: new kwargs
#     182
# --> 183     return pandas_gbq.read_gbq(
#     184         query,
#     185         project_id=project_id,
#
# ...
